# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import keras
import tensorflow as tf

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score

from typing import List

tf.config.list_physical_devices('GPU')
# Out:
# 2024-06-10 00:28:56.747380: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-10 00:28:56.747525: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-10 00:28:56.880517: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import splitfolders
import shutil

# %%
def recursive_rmdir(folder):
    for item in os.listdir(folder):
        item_path = os.path.join(folder, item)
        
        if os.path.isdir(item_path):
            recursive_rmdir(item_path)
            os.rmdir(item_path)
        else:
            os.remove(item_path)
            

def organize_dataset(source_folder, destination_folder):    
    if os.path.exists(destination_folder):
        recursive_rmdir(destination_folder)
    
    # Discover all classes
    classes = set()
    for subfolder in os.listdir(source_folder):
        current_folder = os.path.join(source_folder, subfolder)
        discovered_classes = os.listdir(current_folder)
        classes = classes.union(discovered_classes)
    classes = list(classes)
    classes.sort()

    # Create a folder for each class
    if not os.path.exists(destination_folder):
        os.mkdir(destination_folder)
    
    for _class in classes:
        class_directory = os.path.join(destination_folder, _class)
        os.mkdir(class_directory)
    
    for subfolder in os.listdir(source_folder):
        current_path = os.path.join(source_folder, subfolder)
        for class_folder in os.listdir(current_path):
            current_path = os.path.join(source_folder, subfolder, class_folder)
            for file in os.listdir(current_path):
                
                file_source_path = os.path.join(
                    source_folder,
                    subfolder,
                    class_folder,
                    file
                )
                
                file_destination_path = os.path.join(
                    destination_folder,
                    class_folder,
                    file
                )
                
                shutil.copy2(
                    file_source_path,
                    file_destination_path,
                )

    return classes

# %%
def train_test_validation_split(
    source: str,
    destination: str,
    seed: int | None = None
):
    if seed is None:
        seed = np.random.randint(999999)
    print(f"Dataset's split seed is {seed}")

    if not os.path.isdir(destination):
        splitfolders.ratio(source, output=destination,
            seed=seed, ratio=(.6, .2, .2), move=False)

# %%
def get_true_and_predicted_labels(model, dataset):
    y_true = []
    y_pred = []
    
    for X_batch, y_batch in dataset:
        y_batch_pred = np.argmax(model.predict(X_batch, verbose=0), axis=1)
        
        y_true.append(y_batch)
        y_pred.append(y_batch_pred)
    
    y_true = [y_batch.numpy() for y_batch in y_true]
    
    return np.concatenate(y_true), np.concatenate(y_pred)

# %%
classes = organize_dataset(
    os.path.join("/", "kaggle", "input", "chest-xray-pneumoniacovid19tuberculosis"),
    os.path.join("/", "kaggle", "working", "temp"),
)
train_test_validation_split(
    os.path.join("/", "kaggle", "working", "temp"),
    os.path.join("/", "kaggle", "working", "dataset"),
    seed=0
)

print("Found classes:", classes)
# Out:
# Dataset's split seed is 0
# Copying files: 7132 files [00:02, 2513.00 files/s]
# Found classes: ['COVID19', 'NORMAL', 'PNEUMONIA', 'TURBERCULOSIS']

# %%
print("\n[ TRAIN DATASET ]")
train_dataset = keras.utils.image_dataset_from_directory(
    os.path.join("/", "kaggle", "working", "dataset", "train"),
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=32,
    image_size=(224, 224),
    shuffle=True,
    interpolation='bilinear',
)

print("\n[ VALIDATION DATASET ]")
validation_dataset = keras.utils.image_dataset_from_directory(
    os.path.join("/", "kaggle", "working", "dataset", "val"),
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=32,
    image_size=(224, 224),
    shuffle=True,
    interpolation='bilinear',
)

print("\n[ TEST DATASET ]")
test_dataset = keras.utils.image_dataset_from_directory(
    os.path.join("/", "kaggle", "working", "dataset", "test"),
    labels='inferred',
    label_mode='int',
    color_mode='rgb',
    batch_size=32,
    image_size=(224, 224),
    shuffle=True,
    interpolation='bilinear',
)
# Out:
# [ TRAIN DATASET ]
# Found 4277 files belonging to 4 classes.
#
# [ VALIDATION DATASET ]
# Found 1425 files belonging to 4 classes.
#
# [ TEST DATASET ]
# Found 1430 files belonging to 4 classes.

# %%
# Model creation
vgg_16 = keras.applications.VGG16(
    include_top=False,
    weights="imagenet",
    input_shape=(224, 224, 3),
    pooling="max",
)
vgg_16.trainable = False

model = keras.Sequential([
    keras.layers.Rescaling(1./255),
    vgg_16,
    keras.layers.Flatten(),
    keras.layers.Dense(4096, activation="relu"),
    keras.layers.Dense(4096, activation="relu"),
    keras.layers.Dense(4, activation="softmax"),
], name="model")

model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(name="loss"),
    optimizer=keras.optimizers.Adam(learning_rate=0.0001, name="optimizer"),
    metrics=["accuracy"],
)
model.build((None, 224, 224, 3))
model.summary()

model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=9999,
    callbacks=[
        keras.callbacks.ModelCheckpoint(
            model.name + '.keras',
            monitor='val_accuracy',
            verbose=1,
            save_best_only=True,
            save_weights_only=False,
            mode='auto',
            save_freq="epoch",
        ),
        keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            min_delta=0,
            patience=20,
            verbose=1,
            mode='auto',
        ),
    ],
)

# Fine tuning
vgg_16.trainable = True

model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(name="loss"),
    optimizer=keras.optimizers.Adam(learning_rate=0.000005, name="optimizer"),
    metrics=["accuracy"],
)

model.summary()

model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=9999,
    callbacks=[
        keras.callbacks.ModelCheckpoint(
            model.name + '.keras',
            monitor='val_accuracy',
            verbose=1,
            save_best_only=True,
            save_weights_only=False,
            mode='auto',
            save_freq="epoch",
        ),
        keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            min_delta=0,
            patience=50,
            verbose=1,
            mode='auto',
        ),
    ],
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 4)                 16388
#
# =================================================================
# Total params: 33613636 (128.23 MB)
# Trainable params: 18898948 (72.09 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________
# Epoch 1/9999
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717979429.010129      85 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 134/134 [==============================] - ETA: 0s - loss: 0.6454 - accuracy: 0.8595
# Epoch 1: val_accuracy improved from -inf to 0.91789, saving model to model.keras
# 134/134 [==============================] - 43s 258ms/step - loss: 0.6454 - accuracy: 0.8595 - val_loss: 3.8635 - val_accuracy: 0.9179
# Epoch 2/9999
# 134/134 [==============================] - ETA: 0s - loss: 12.6940 - accuracy: 0.9177
# Epoch 2: val_accuracy did not improve from 0.91789
# 134/134 [==============================] - 29s 205ms/step - loss: 12.6940 - accuracy: 0.9177 - val_loss: 30.4362 - val_accuracy: 0.8765
# Epoch 3/9999
# 134/134 [==============================] - ETA: 0s - loss: 2.5593 - accuracy: 0.9387
# Epoch 3: val_accuracy did not improve from 0.91789
# 134/134 [==============================] - 29s 207ms/step - loss: 2.5593 - accuracy: 0.9387 - val_loss: 4.3415 - val_accuracy: 0.9137
# Epoch 4/9999
# 134/134 [==============================] - ETA: 0s - loss: 1.5456 - accuracy: 0.9467
# Epoch 4: val_accuracy improved from 0.91789 to 0.92982, saving model to model.keras
# 134/134 [==============================] - 30s 218ms/step - loss: 1.5456 - accuracy: 0.9467 - val_loss: 3.5575 - val_accuracy: 0.9298
# Epoch 5/9999
# 134/134 [==============================] - ETA: 0s - loss: 1.5825 - accuracy: 0.9507
# Epoch 5: val_accuracy did not improve from 0.92982
# 134/134 [==============================] - 29s 207ms/step - loss: 1.5825 - accuracy: 0.9507 - val_loss: 3.1210 - val_accuracy: 0.8919
# Epoch 6/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.2205 - accuracy: 0.9497
# Epoch 6: val_accuracy improved from 0.92982 to 0.93193, saving model to model.keras
# 134/134 [==============================] - 31s 217ms/step - loss: 0.2205 - accuracy: 0.9497 - val_loss: 0.8344 - val_accuracy: 0.9319
# Epoch 7/9999
# 134/134 [==============================] - ETA: 0s - loss: 1.1992 - accuracy: 0.9532
# Epoch 7: val_accuracy did not improve from 0.93193
# 134/134 [==============================] - 29s 205ms/step - loss: 1.1992 - accuracy: 0.9532 - val_loss: 3.3044 - val_accuracy: 0.9235
# Epoch 8/9999
# 134/134 [==============================] - ETA: 0s - loss: 1.4344 - accuracy: 0.9584
# Epoch 8: val_accuracy did not improve from 0.93193
# 134/134 [==============================] - 29s 206ms/step - loss: 1.4344 - accuracy: 0.9584 - val_loss: 2.4254 - val_accuracy: 0.9298
# Epoch 9/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.7837 - accuracy: 0.9659
# Epoch 9: val_accuracy did not improve from 0.93193
# 134/134 [==============================] - 29s 206ms/step - loss: 0.7837 - accuracy: 0.9659 - val_loss: 0.8612 - val_accuracy: 0.9263
# Epoch 10/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.4690 - accuracy: 0.9638
# Epoch 10: val_accuracy did not improve from 0.93193
# 134/134 [==============================] - 29s 208ms/step - loss: 0.4690 - accuracy: 0.9638 - val_loss: 1.3128 - val_accuracy: 0.9214
# Epoch 11/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.4932 - accuracy: 0.9628
# Epoch 11: val_accuracy did not improve from 0.93193
# 134/134 [==============================] - 29s 209ms/step - loss: 0.4932 - accuracy: 0.9628 - val_loss: 1.5721 - val_accuracy: 0.9312
# Epoch 12/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.6478 - accuracy: 0.9731
# Epoch 12: val_accuracy did not improve from 0.93193
# 134/134 [==============================] - 29s 210ms/step - loss: 0.6478 - accuracy: 0.9731 - val_loss: 1.6750 - val_accuracy: 0.9305
# Epoch 13/9999
# 134/134 [==============================] - ETA: 0s - loss: 1.1599 - accuracy: 0.9694
# Epoch 13: val_accuracy did not improve from 0.93193
# 134/134 [==============================] - 29s 205ms/step - loss: 1.1599 - accuracy: 0.9694 - val_loss: 1.7428 - val_accuracy: 0.9270
# Epoch 14/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.3063 - accuracy: 0.9724
# Epoch 14: val_accuracy did not improve from 0.93193
# 134/134 [==============================] - 29s 207ms/step - loss: 0.3063 - accuracy: 0.9724 - val_loss: 0.8014 - val_accuracy: 0.9312
# Epoch 15/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.3898 - accuracy: 0.9783
# Epoch 15: val_accuracy did not improve from 0.93193
# 134/134 [==============================] - 29s 206ms/step - loss: 0.3898 - accuracy: 0.9783 - val_loss: 1.1479 - val_accuracy: 0.9200
# Epoch 16/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.7075 - accuracy: 0.9731
# Epoch 16: val_accuracy did not improve from 0.93193
# 134/134 [==============================] - 29s 210ms/step - loss: 0.7075 - accuracy: 0.9731 - val_loss: 2.3091 - val_accuracy: 0.7130
# Epoch 17/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.4442 - accuracy: 0.9645
# Epoch 17: val_accuracy improved from 0.93193 to 0.93404, saving model to model.keras
# 134/134 [==============================] - 31s 219ms/step - loss: 0.4442 - accuracy: 0.9645 - val_loss: 1.0225 - val_accuracy: 0.9340
# Epoch 18/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.4978 - accuracy: 0.9794
# Epoch 18: val_accuracy did not improve from 0.93404
# 134/134 [==============================] - 28s 203ms/step - loss: 0.4978 - accuracy: 0.9794 - val_loss: 1.1932 - val_accuracy: 0.9270
# Epoch 19/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.4361 - accuracy: 0.9649
# Epoch 19: val_accuracy did not improve from 0.93404
# 134/134 [==============================] - 28s 204ms/step - loss: 0.4361 - accuracy: 0.9649 - val_loss: 0.8807 - val_accuracy: 0.9312
# Epoch 20/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.5643 - accuracy: 0.9813
# Epoch 20: val_accuracy did not improve from 0.93404
# 134/134 [==============================] - 28s 204ms/step - loss: 0.5643 - accuracy: 0.9813 - val_loss: 0.6085 - val_accuracy: 0.9319
# Epoch 21/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.2949 - accuracy: 0.9787
# Epoch 21: val_accuracy did not improve from 0.93404
# 134/134 [==============================] - 29s 205ms/step - loss: 0.2949 - accuracy: 0.9787 - val_loss: 0.8502 - val_accuracy: 0.9214
# Epoch 22/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.3288 - accuracy: 0.9855
# Epoch 22: val_accuracy did not improve from 0.93404
# 134/134 [==============================] - 29s 208ms/step - loss: 0.3288 - accuracy: 0.9855 - val_loss: 0.5899 - val_accuracy: 0.9137
# Epoch 23/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.3624 - accuracy: 0.9855
# Epoch 23: val_accuracy improved from 0.93404 to 0.93474, saving model to model.keras
# 134/134 [==============================] - 30s 213ms/step - loss: 0.3624 - accuracy: 0.9855 - val_loss: 1.0792 - val_accuracy: 0.9347
# Epoch 24/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9822
# Epoch 24: val_accuracy improved from 0.93474 to 0.93544, saving model to model.keras
# 134/134 [==============================] - 30s 217ms/step - loss: 0.2165 - accuracy: 0.9822 - val_loss: 0.3345 - val_accuracy: 0.9354
# Epoch 25/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9897
# Epoch 25: val_accuracy improved from 0.93544 to 0.93614, saving model to model.keras
# 134/134 [==============================] - 30s 213ms/step - loss: 0.1845 - accuracy: 0.9897 - val_loss: 0.2131 - val_accuracy: 0.9361
# Epoch 26/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.4307 - accuracy: 0.9787
# Epoch 26: val_accuracy did not improve from 0.93614
# 134/134 [==============================] - 29s 205ms/step - loss: 0.4307 - accuracy: 0.9787 - val_loss: 0.9175 - val_accuracy: 0.9361
# Epoch 27/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.3352 - accuracy: 0.9813
# Epoch 27: val_accuracy did not improve from 0.93614
# 134/134 [==============================] - 29s 207ms/step - loss: 0.3352 - accuracy: 0.9813 - val_loss: 0.8340 - val_accuracy: 0.9200
# Epoch 28/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.3355 - accuracy: 0.9888
# Epoch 28: val_accuracy improved from 0.93614 to 0.93895, saving model to model.keras
# 134/134 [==============================] - 30s 215ms/step - loss: 0.3355 - accuracy: 0.9888 - val_loss: 1.8390 - val_accuracy: 0.9389
# Epoch 29/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.3189 - accuracy: 0.9874
# Epoch 29: val_accuracy did not improve from 0.93895
# 134/134 [==============================] - 29s 207ms/step - loss: 0.3189 - accuracy: 0.9874 - val_loss: 0.5430 - val_accuracy: 0.9305
# Epoch 30/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1564 - accuracy: 0.9911
# Epoch 30: val_accuracy did not improve from 0.93895
# 134/134 [==============================] - 29s 207ms/step - loss: 0.1564 - accuracy: 0.9911 - val_loss: 0.5301 - val_accuracy: 0.9368
# Epoch 31/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.3651 - accuracy: 0.9935
# Epoch 31: val_accuracy improved from 0.93895 to 0.94526, saving model to model.keras
# 134/134 [==============================] - 30s 215ms/step - loss: 0.3651 - accuracy: 0.9935 - val_loss: 0.8741 - val_accuracy: 0.9453
# Epoch 32/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1322 - accuracy: 0.9939
# Epoch 32: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 208ms/step - loss: 0.1322 - accuracy: 0.9939 - val_loss: 0.3501 - val_accuracy: 0.9439
# Epoch 33/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.4356 - accuracy: 0.9918
# Epoch 33: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 206ms/step - loss: 0.4356 - accuracy: 0.9918 - val_loss: 1.1817 - val_accuracy: 0.9277
# Epoch 34/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.9890
# Epoch 34: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 208ms/step - loss: 0.1314 - accuracy: 0.9890 - val_loss: 0.3819 - val_accuracy: 0.9361
# Epoch 35/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.3468 - accuracy: 0.9925
# Epoch 35: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 210ms/step - loss: 0.3468 - accuracy: 0.9925 - val_loss: 1.1755 - val_accuracy: 0.9116
# Epoch 36/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9867
# Epoch 36: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 210ms/step - loss: 0.2445 - accuracy: 0.9867 - val_loss: 0.3250 - val_accuracy: 0.9326
# Epoch 37/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9958
# Epoch 37: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 210ms/step - loss: 0.1137 - accuracy: 0.9958 - val_loss: 0.6276 - val_accuracy: 0.9396
# Epoch 38/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.9874
# Epoch 38: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 207ms/step - loss: 0.5098 - accuracy: 0.9874 - val_loss: 0.9963 - val_accuracy: 0.9291
# Epoch 39/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.4096 - accuracy: 0.9958
# Epoch 39: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 209ms/step - loss: 0.4096 - accuracy: 0.9958 - val_loss: 1.2164 - val_accuracy: 0.9389
# Epoch 40/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.3257 - accuracy: 0.9946
# Epoch 40: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 204ms/step - loss: 0.3257 - accuracy: 0.9946 - val_loss: 0.5749 - val_accuracy: 0.9333
# Epoch 41/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1261 - accuracy: 0.9888
# Epoch 41: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 28s 201ms/step - loss: 0.1261 - accuracy: 0.9888 - val_loss: 0.4280 - val_accuracy: 0.9333
# Epoch 42/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.2870 - accuracy: 0.9923
# Epoch 42: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 204ms/step - loss: 0.2870 - accuracy: 0.9923 - val_loss: 1.0507 - val_accuracy: 0.9333
# Epoch 43/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.9986
# Epoch 43: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 207ms/step - loss: 0.0915 - accuracy: 0.9986 - val_loss: 0.7694 - val_accuracy: 0.9375
# Epoch 44/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0622 - accuracy: 0.9928
# Epoch 44: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 209ms/step - loss: 0.0622 - accuracy: 0.9928 - val_loss: 0.4809 - val_accuracy: 0.9116
# Epoch 45/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.9897
# Epoch 45: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 204ms/step - loss: 0.2648 - accuracy: 0.9897 - val_loss: 0.4380 - val_accuracy: 0.9368
# Epoch 46/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9956
# Epoch 46: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 205ms/step - loss: 0.0776 - accuracy: 0.9956 - val_loss: 0.4163 - val_accuracy: 0.9354
# Epoch 47/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.2856 - accuracy: 0.9965
# Epoch 47: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 205ms/step - loss: 0.2856 - accuracy: 0.9965 - val_loss: 0.9788 - val_accuracy: 0.9354
# Epoch 48/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9977
# Epoch 48: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 206ms/step - loss: 0.0914 - accuracy: 0.9977 - val_loss: 0.4953 - val_accuracy: 0.9361
# Epoch 49/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.9958
# Epoch 49: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 28s 201ms/step - loss: 0.1412 - accuracy: 0.9958 - val_loss: 0.4423 - val_accuracy: 0.9333
# Epoch 50/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9956
# Epoch 50: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 28s 203ms/step - loss: 0.0361 - accuracy: 0.9956 - val_loss: 0.3362 - val_accuracy: 0.9382
# Epoch 51/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.2126 - accuracy: 0.9970
# Epoch 51: val_accuracy did not improve from 0.94526
# 134/134 [==============================] - 29s 207ms/step - loss: 0.2126 - accuracy: 0.9970 - val_loss: 0.8495 - val_accuracy: 0.9354
# Epoch 51: early stopping
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 4096)              2101248
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dense_2 (Dense)             (None, 4)                 16388
#
# =================================================================
# Total params: 33613636 (128.23 MB)
# Trainable params: 33613636 (128.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9906
# Epoch 1: val_accuracy improved from -inf to 0.92000, saving model to model.keras
# 134/134 [==============================] - 54s 308ms/step - loss: 0.1917 - accuracy: 0.9906 - val_loss: 1.2171 - val_accuracy: 0.9200
# Epoch 2/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9878
# Epoch 2: val_accuracy improved from 0.92000 to 0.94105, saving model to model.keras
# 134/134 [==============================] - 39s 281ms/step - loss: 0.1710 - accuracy: 0.9878 - val_loss: 0.8218 - val_accuracy: 0.9411
# Epoch 3/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9913
# Epoch 3: val_accuracy improved from 0.94105 to 0.94947, saving model to model.keras
# 134/134 [==============================] - 39s 281ms/step - loss: 0.1783 - accuracy: 0.9913 - val_loss: 0.5081 - val_accuracy: 0.9495
# Epoch 4/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9963
# Epoch 4: val_accuracy did not improve from 0.94947
# 134/134 [==============================] - 37s 268ms/step - loss: 0.1265 - accuracy: 0.9963 - val_loss: 0.8585 - val_accuracy: 0.9319
# Epoch 5/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9956
# Epoch 5: val_accuracy did not improve from 0.94947
# 134/134 [==============================] - 37s 266ms/step - loss: 0.1341 - accuracy: 0.9956 - val_loss: 0.6370 - val_accuracy: 0.9460
# Epoch 6/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1239 - accuracy: 0.9981
# Epoch 6: val_accuracy improved from 0.94947 to 0.95228, saving model to model.keras
# 134/134 [==============================] - 39s 279ms/step - loss: 0.1239 - accuracy: 0.9981 - val_loss: 0.4633 - val_accuracy: 0.9523
# Epoch 7/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9984
# Epoch 7: val_accuracy improved from 0.95228 to 0.95509, saving model to model.keras
# 134/134 [==============================] - 39s 279ms/step - loss: 0.0606 - accuracy: 0.9984 - val_loss: 0.3082 - val_accuracy: 0.9551
# Epoch 8/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.3014 - accuracy: 0.9953
# Epoch 8: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 265ms/step - loss: 0.3014 - accuracy: 0.9953 - val_loss: 1.0247 - val_accuracy: 0.9460
# Epoch 9/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1657 - accuracy: 0.9871
# Epoch 9: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 264ms/step - loss: 0.1657 - accuracy: 0.9871 - val_loss: 0.5093 - val_accuracy: 0.9453
# Epoch 10/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1466 - accuracy: 0.9944
# Epoch 10: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 268ms/step - loss: 0.1466 - accuracy: 0.9944 - val_loss: 0.6310 - val_accuracy: 0.9326
# Epoch 11/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9951
# Epoch 11: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0967 - accuracy: 0.9951 - val_loss: 0.5503 - val_accuracy: 0.9516
# Epoch 12/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9981
# Epoch 12: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0798 - accuracy: 0.9981 - val_loss: 0.4084 - val_accuracy: 0.9523
# Epoch 13/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0700 - accuracy: 0.9979
# Epoch 13: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0700 - accuracy: 0.9979 - val_loss: 0.5000 - val_accuracy: 0.9502
# Epoch 14/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9979
# Epoch 14: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0764 - accuracy: 0.9979 - val_loss: 0.4900 - val_accuracy: 0.9495
# Epoch 15/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9977
# Epoch 15: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0560 - accuracy: 0.9977 - val_loss: 0.4500 - val_accuracy: 0.9509
# Epoch 16/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9984
# Epoch 16: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0176 - accuracy: 0.9984 - val_loss: 0.3208 - val_accuracy: 0.9516
# Epoch 17/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9977
# Epoch 17: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0154 - accuracy: 0.9977 - val_loss: 0.2826 - val_accuracy: 0.9509
# Epoch 18/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9984
# Epoch 18: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0199 - accuracy: 0.9984 - val_loss: 0.2954 - val_accuracy: 0.9516
# Epoch 19/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9967
# Epoch 19: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 263ms/step - loss: 0.0274 - accuracy: 0.9967 - val_loss: 0.2514 - val_accuracy: 0.9530
# Epoch 20/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9977
# Epoch 20: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 263ms/step - loss: 0.0345 - accuracy: 0.9977 - val_loss: 0.6602 - val_accuracy: 0.9523
# Epoch 21/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0313 - accuracy: 0.9977
# Epoch 21: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0313 - accuracy: 0.9977 - val_loss: 0.2516 - val_accuracy: 0.9523
# Epoch 22/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9958
# Epoch 22: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0351 - accuracy: 0.9958 - val_loss: 0.2395 - val_accuracy: 0.9502
# Epoch 23/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0445 - accuracy: 0.9977
# Epoch 23: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0445 - accuracy: 0.9977 - val_loss: 0.3190 - val_accuracy: 0.9495
# Epoch 24/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9979
# Epoch 24: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 36s 263ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.2676 - val_accuracy: 0.9523
# Epoch 25/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9981
# Epoch 25: val_accuracy did not improve from 0.95509
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.3002 - val_accuracy: 0.9551
# Epoch 26/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9970
# Epoch 26: val_accuracy improved from 0.95509 to 0.95649, saving model to model.keras
# 134/134 [==============================] - 39s 279ms/step - loss: 0.0076 - accuracy: 0.9970 - val_loss: 0.2601 - val_accuracy: 0.9565
# Epoch 27/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9991
# Epoch 27: val_accuracy did not improve from 0.95649
# 134/134 [==============================] - 38s 267ms/step - loss: 0.0088 - accuracy: 0.9991 - val_loss: 0.3169 - val_accuracy: 0.9544
# Epoch 28/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9986
# Epoch 28: val_accuracy did not improve from 0.95649
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0063 - accuracy: 0.9986 - val_loss: 0.2803 - val_accuracy: 0.9523
# Epoch 29/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9977
# Epoch 29: val_accuracy improved from 0.95649 to 0.95719, saving model to model.keras
# 134/134 [==============================] - 39s 277ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.3299 - val_accuracy: 0.9572
# Epoch 30/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9986
# Epoch 30: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0102 - accuracy: 0.9986 - val_loss: 0.2630 - val_accuracy: 0.9572
# Epoch 31/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9993
# Epoch 31: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.2363 - val_accuracy: 0.9537
# Epoch 32/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9993
# Epoch 32: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 40s 291ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.2084 - val_accuracy: 0.9558
# Epoch 33/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9988
# Epoch 33: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0033 - accuracy: 0.9988 - val_loss: 0.2372 - val_accuracy: 0.9537
# Epoch 34/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9977
# Epoch 34: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.2331 - val_accuracy: 0.9558
# Epoch 35/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9984
# Epoch 35: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 36s 262ms/step - loss: 0.0115 - accuracy: 0.9984 - val_loss: 0.2570 - val_accuracy: 0.9523
# Epoch 36/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9986
# Epoch 36: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.2996 - val_accuracy: 0.9558
# Epoch 37/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9991
# Epoch 37: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0017 - accuracy: 0.9991 - val_loss: 0.2487 - val_accuracy: 0.9544
# Epoch 38/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9986
# Epoch 38: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0071 - accuracy: 0.9986 - val_loss: 0.2540 - val_accuracy: 0.9530
# Epoch 39/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9984
# Epoch 39: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.2588 - val_accuracy: 0.9523
# Epoch 40/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9986
# Epoch 40: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 263ms/step - loss: 0.0026 - accuracy: 0.9986 - val_loss: 0.2531 - val_accuracy: 0.9516
# Epoch 41/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9984
# Epoch 41: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0238 - accuracy: 0.9984 - val_loss: 0.4223 - val_accuracy: 0.9509
# Epoch 42/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9670
# Epoch 42: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 264ms/step - loss: 0.1431 - accuracy: 0.9670 - val_loss: 0.2134 - val_accuracy: 0.9404
# Epoch 43/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0514 - accuracy: 0.9811
# Epoch 43: val_accuracy did not improve from 0.95719
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0514 - accuracy: 0.9811 - val_loss: 0.2329 - val_accuracy: 0.9396
# Epoch 44/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9967
# Epoch 44: val_accuracy improved from 0.95719 to 0.96632, saving model to model.keras
# 134/134 [==============================] - 39s 279ms/step - loss: 0.0195 - accuracy: 0.9967 - val_loss: 0.1926 - val_accuracy: 0.9663
# Epoch 45/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9986
# Epoch 45: val_accuracy improved from 0.96632 to 0.96702, saving model to model.keras
# 134/134 [==============================] - 39s 280ms/step - loss: 0.0137 - accuracy: 0.9986 - val_loss: 0.1893 - val_accuracy: 0.9670
# Epoch 46/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9979
# Epoch 46: val_accuracy improved from 0.96702 to 0.97193, saving model to model.keras
# 134/134 [==============================] - 38s 277ms/step - loss: 0.0047 - accuracy: 0.9979 - val_loss: 0.1478 - val_accuracy: 0.9719
# Epoch 47/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9988
# Epoch 47: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 36s 263ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.1599 - val_accuracy: 0.9712
# Epoch 48/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9970
# Epoch 48: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0224 - accuracy: 0.9970 - val_loss: 0.1547 - val_accuracy: 0.9705
# Epoch 49/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9956
# Epoch 49: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0406 - accuracy: 0.9956 - val_loss: 0.1618 - val_accuracy: 0.9698
# Epoch 50/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9977
# Epoch 50: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0147 - accuracy: 0.9977 - val_loss: 0.2403 - val_accuracy: 0.9663
# Epoch 51/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9967
# Epoch 51: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0183 - accuracy: 0.9967 - val_loss: 0.1846 - val_accuracy: 0.9677
# Epoch 52/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9984
# Epoch 52: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0170 - accuracy: 0.9984 - val_loss: 0.2088 - val_accuracy: 0.9677
# Epoch 53/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9984
# Epoch 53: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 263ms/step - loss: 0.0090 - accuracy: 0.9984 - val_loss: 0.1839 - val_accuracy: 0.9684
# Epoch 54/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9986
# Epoch 54: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0081 - accuracy: 0.9986 - val_loss: 0.1462 - val_accuracy: 0.9698
# Epoch 55/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9995
# Epoch 55: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.1821 - val_accuracy: 0.9691
# Epoch 56/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9970
# Epoch 56: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 267ms/step - loss: 0.0136 - accuracy: 0.9970 - val_loss: 0.1568 - val_accuracy: 0.9698
# Epoch 57/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9979
# Epoch 57: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0113 - accuracy: 0.9979 - val_loss: 0.1969 - val_accuracy: 0.9670
# Epoch 58/9999
# 134/134 [==============================] - ETA: 0s - loss: 7.9679e-04 - accuracy: 1.0000
# Epoch 58: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 7.9679e-04 - accuracy: 1.0000 - val_loss: 0.2162 - val_accuracy: 0.9712
# Epoch 59/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9993
# Epoch 59: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.1641 - val_accuracy: 0.9712
# Epoch 60/9999
# 134/134 [==============================] - ETA: 0s - loss: 3.9359e-04 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 263ms/step - loss: 3.9359e-04 - accuracy: 1.0000 - val_loss: 0.1956 - val_accuracy: 0.9670
# Epoch 61/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9993
# Epoch 61: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 0.2141 - val_accuracy: 0.9684
# Epoch 62/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9993
# Epoch 62: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 38s 266ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.1991 - val_accuracy: 0.9684
# Epoch 63/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9984
# Epoch 63: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0034 - accuracy: 0.9984 - val_loss: 0.1615 - val_accuracy: 0.9691
# Epoch 64/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9984
# Epoch 64: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0106 - accuracy: 0.9984 - val_loss: 0.2416 - val_accuracy: 0.9684
# Epoch 65/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9967
# Epoch 65: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.1664 - val_accuracy: 0.9677
# Epoch 66/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9986
# Epoch 66: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0077 - accuracy: 0.9986 - val_loss: 0.1846 - val_accuracy: 0.9684
# Epoch 67/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9979
# Epoch 67: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.1896 - val_accuracy: 0.9670
# Epoch 68/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9988
# Epoch 68: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 38s 268ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 0.1703 - val_accuracy: 0.9670
# Epoch 69/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9991
# Epoch 69: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0017 - accuracy: 0.9991 - val_loss: 0.1926 - val_accuracy: 0.9684
# Epoch 70/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.9993
# Epoch 70: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.1793 - val_accuracy: 0.9698
# Epoch 71/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9993
# Epoch 71: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0012 - accuracy: 0.9993 - val_loss: 0.1535 - val_accuracy: 0.9705
# Epoch 72/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9993
# Epoch 72: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.1752 - val_accuracy: 0.9705
# Epoch 73/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9993
# Epoch 73: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0015 - accuracy: 0.9993 - val_loss: 0.1686 - val_accuracy: 0.9719
# Epoch 74/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9979
# Epoch 74: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 38s 268ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.1716 - val_accuracy: 0.9677
# Epoch 75/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9972
# Epoch 75: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0105 - accuracy: 0.9972 - val_loss: 0.1995 - val_accuracy: 0.9698
# Epoch 76/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9970
# Epoch 76: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 263ms/step - loss: 0.0380 - accuracy: 0.9970 - val_loss: 0.2203 - val_accuracy: 0.9684
# Epoch 77/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0790 - accuracy: 0.9752
# Epoch 77: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 263ms/step - loss: 0.0790 - accuracy: 0.9752 - val_loss: 0.1789 - val_accuracy: 0.9460
# Epoch 78/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9916
# Epoch 78: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0255 - accuracy: 0.9916 - val_loss: 0.2783 - val_accuracy: 0.9425
# Epoch 79/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9946
# Epoch 79: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0183 - accuracy: 0.9946 - val_loss: 0.1918 - val_accuracy: 0.9593
# Epoch 80/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9958
# Epoch 80: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0167 - accuracy: 0.9958 - val_loss: 0.1842 - val_accuracy: 0.9607
# Epoch 81/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0286 - accuracy: 0.9972
# Epoch 81: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0286 - accuracy: 0.9972 - val_loss: 0.1626 - val_accuracy: 0.9642
# Epoch 82/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 0.9977
# Epoch 82: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 267ms/step - loss: 0.0050 - accuracy: 0.9977 - val_loss: 0.1864 - val_accuracy: 0.9600
# Epoch 83/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9984
# Epoch 83: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.1709 - val_accuracy: 0.9649
# Epoch 84/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9991
# Epoch 84: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.1992 - val_accuracy: 0.9614
# Epoch 85/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9993
# Epoch 85: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0016 - accuracy: 0.9993 - val_loss: 0.1898 - val_accuracy: 0.9635
# Epoch 86/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9991
# Epoch 86: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 268ms/step - loss: 0.0018 - accuracy: 0.9991 - val_loss: 0.1729 - val_accuracy: 0.9642
# Epoch 87/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9986
# Epoch 87: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0033 - accuracy: 0.9986 - val_loss: 0.1722 - val_accuracy: 0.9635
# Epoch 88/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9986
# Epoch 88: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 263ms/step - loss: 0.0071 - accuracy: 0.9986 - val_loss: 0.1865 - val_accuracy: 0.9628
# Epoch 89/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9991
# Epoch 89: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.1877 - val_accuracy: 0.9656
# Epoch 90/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9988
# Epoch 90: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 263ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.2134 - val_accuracy: 0.9684
# Epoch 91/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9993
# Epoch 91: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 264ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1821 - val_accuracy: 0.9677
# Epoch 92/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9995
# Epoch 92: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.1700 - val_accuracy: 0.9656
# Epoch 93/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9986
# Epoch 93: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 268ms/step - loss: 0.0025 - accuracy: 0.9986 - val_loss: 0.2099 - val_accuracy: 0.9635
# Epoch 94/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9993
# Epoch 94: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.1639 - val_accuracy: 0.9719
# Epoch 95/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9995
# Epoch 95: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 265ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.1584 - val_accuracy: 0.9670
# Epoch 96/9999
# 134/134 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9991
# Epoch 96: val_accuracy did not improve from 0.97193
# 134/134 [==============================] - 37s 266ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.2126 - val_accuracy: 0.9684
# Epoch 96: early stopping

# %%
best_model = keras.saving.load_model("model.keras")
y_true, y_pred = get_true_and_predicted_labels(best_model, test_dataset)

model_accuracy = accuracy_score(y_true, y_pred)

# Saving confusion matrix
ConfusionMatrixDisplay.from_predictions(
    y_true, y_pred,
    display_labels=classes
)
plt.savefig("confusion_matrix.png")

print(classification_report(y_true, y_pred, target_names=classes))
with open("classification_report.txt", "w") as file:
    file.write(classification_report(y_true, y_pred, target_names=classes))
# Out:
#                precision    recall  f1-score   support
#
#       COVID19       0.95      0.92      0.93       116
#        NORMAL       0.94      0.95      0.95       318
#     PNEUMONIA       0.98      0.98      0.98       856
# TURBERCULOSIS       0.96      0.97      0.97       140
#
#      accuracy                           0.97      1430
#     macro avg       0.96      0.95      0.96      1430
#  weighted avg       0.97      0.97      0.97      1430

# %%
classes = ["COVID-19", "NORMAL", "PNEUMONIA", "TURBECULOSIS"]

rows, columns = 4, 4

for images, labels in test_dataset.take(1):
    plt.subplots(rows, columns, layout="constrained")
    i = 1
    
    predictions = np.argmax(best_model.predict(images, verbose=0), axis=1)
    
    for image, label_true, label_pred in zip(
        images.numpy()[:rows*columns],
        labels.numpy()[:rows*columns],
        predictions[:rows*columns]
    ):
        plt.subplot(rows, columns, i)
        plt.imshow(image.astype("uint8"))
        plt.title(f"{classes[label_true]}\n{classes[label_pred]}")
        plt.axis("off")
        i += 1
